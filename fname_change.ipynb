# %%
# 파일명 변경

# %%
import pandas as pd
import openpyxl as xl
import sys
import re
import os
from os import listdir
from os.path import isfile, join

# %%
wav_path = './200623_3models_4speakers/3_trans+enhancer+vocgan/male_배진영/'

# %%
files = listdir(wav_path)
print(len(files))
files
# Out:
# 200
# ['NC_Celeb_CixJinyoung_001.wav',
#  'NC_Celeb_CixJinyoung_002.wav',
#  'NC_Celeb_CixJinyoung_003.wav',
#  'NC_Celeb_CixJinyoung_004.wav',
#  'NC_Celeb_CixJinyoung_005.wav',
#  'NC_Celeb_CixJinyoung_006.wav',
#  'NC_Celeb_CixJinyoung_007.wav',
#  'NC_Celeb_CixJinyoung_008.wav',
#  'NC_Celeb_CixJinyoung_009.wav',
#  'NC_Celeb_CixJinyoung_010.wav',
#  'NC_Celeb_CixJinyoung_011.wav',
#  'NC_Celeb_CixJinyoung_012.wav',
#  'NC_Celeb_CixJinyoung_013.wav',
#  'NC_Celeb_CixJinyoung_014.wav',
#  'NC_Celeb_CixJinyoung_015.wav',
#  'NC_Celeb_CixJinyoung_016.wav',
#  'NC_Celeb_CixJinyoung_017.wav',
#  'NC_Celeb_CixJinyoung_018.wav',
#  'NC_Celeb_CixJinyoung_019.wav',
#  'NC_Celeb_CixJinyoung_020.wav',
#  'NC_Celeb_CixJinyoung_021.wav',
#  'NC_Celeb_CixJinyoung_022.wav',
#  'NC_Celeb_CixJinyoung_023.wav',
#  'NC_Celeb_CixJinyoung_024.wav',
#  'NC_Celeb_CixJinyoung_025.wav',
#  'NC_Celeb_CixJinyoung_026.wav',
#  'NC_Celeb_CixJinyoung_027.wav',
#  'NC_Celeb_CixJinyoung_028.wav',
# ...

# %%
new_name = []

for i in files:
    j = i.split('_')[-1]
    q = i.replace(i, '모델_3_배진영_'+j)
    os.rename('./200623_3models_4speakers/3_trans+enhancer+vocgan/male_배진영/'+i, q)
